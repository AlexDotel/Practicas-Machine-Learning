# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexDotel/Practicas-Machine-Learning/blob/main/Ejercicio_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio Matplotlib
#
# Este cuaderno ofrece un conjunto de ejercicios para distintas tareas con Matplotlib.
#
# Cabe señalar que puede haber más de una forma diferente de responder una pregunta o completar un ejercicio.
#
# Las distintas tareas se detallarán mediante comentarios o texto.

# %%
# Importa el módulo pyplot desde matplotlib como plt y asegúrate de que
# los gráficos aparezcan en el cuaderno usando '%matplotlib inline'
import matplotlib.pyplot as plt
import numpy as np
#Cambio realizado en VS CODE!! PRUEBA!

# %%
# Crea un gráfico simple usando plt.plot()
plt.plot([1, 2, 3], [1, 5, 6])

# %%
# Grafica una sola lista de Python
lista_numeros_aleatorios = np.random.randint(1, 10, 50) # Genera 50 números aleatorios entre 1 y 10
plt.plot(lista_numeros_aleatorios)

# %%
# Crea dos listas, una llamada X, una llamada y, cada una con 5 números en ellas
X = [1, 2, 3, 4, 5]
Y = [2, 3, 5, 7, 11]

# %%
# Grafica X e y (las listas que has creado)
plt.plot(X, Y)

# %% [markdown]
# Hay otra forma de crear gráficos con Matplotlib, se conoce como el método orientado a objetos (OO). Probémoslo.

# %%
# Crea un gráfico usando plt.subplots()
fig, ax = plt.subplots()
ax.plot([1,5,18], [2,10,15])

# %%
# Crea un gráfico usando plt.subplots() y luego agrega X e y en los ejes
fig, ax = plt.subplots()
ax.plot(X, Y)

# %% [markdown]
# Ahora, probemos un pequeño flujo de trabajo de matplotlib.

# %%
# Importar y preparar matplotlib
import matplotlib.pyplot as plt

# Preparar los datos (crear dos listas de 5 números, X e y)
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Configurar la figura y los ejes usando plt.subplots()
fig, ax = plt.subplots()
# Graficar los datos usando ax.plot()

# Agregar datos (X, y) a los ejes
ax.plot(x, y)

# Personalizar el gráfico agregando un título, una etiqueta x y una etiqueta y
ax.set_title('Nivel de agua en el río')
ax.set_xlabel('Tiempo (horas)')
ax.set_ylabel('Nivel de agua (cm)')

# Guardar el gráfico en un archivo usando fig.savefig()
fig.savefig('nivel_agua_rio.png')

# %% [markdown]
# Bien, este es un gráfico lineal simple, ¿qué tal algo un poco diferente?
#
# Para ayudarnos, importaremos NumPy.

# %%
# Importar NumPy como np
import numpy as np

# %%
# Crear una matriz de 100 números espaciados uniformemente entre 0 y 100 usando NumPy y guardarlo en la variable X

# Metodo 1: [Realmente no crea una matriz, sino un array]
x = np.linspace(0, 100, 100)
print(f'Sin Formato:\n Tipo: {type(X)} \n {X}\n')
x.shape = (10, 10)
print(f'Con Formato:\n Tipo: {type(X)} \n {X}')

# Metodo 2:
# x = np.arange(1, 101, 1)
# print(f'Sin Formato:\n Tipo: {type(X)} \n {x}\n')
# x.shape = (10, 10)
# print(f'Con Formato:\n Tipo: {type(X)} \n {x}')
# Out:
# Sin Formato:
#  Tipo: <class 'list'>
#  [1, 2, 3, 4, 5]
#
# Con Formato:
#  Tipo: <class 'list'>
#  [1, 2, 3, 4, 5]

# %%
# Crear un gráfico usando plt.subplots() y trazar X versus X^2 (X al cuadrado)

fig, ax = plt.subplots()
ax.set_title('Matrices uniformes (0-100)')
ax.set_xlabel('X')
ax.set_ylabel('X^2')

# Graficar X versus X^2
ax.plot(x, x**2)
# Guardar el gráfico en un archivo usando fig.savefig()
fig.savefig('matrices_uniformes.png')

# %% [markdown]
# Comenzaremos con gráficos de dispersión.

# %%
# Crea un diagrama de dispersión de X versus el exponencial de X (np.exp(X))
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
# Agregar título y etiquetas
ax.set_title('Diagrama de dispersión de X')
ax.set_xlabel('X')
ax.set_ylabel('np.exp(X)')
# Out:
# Text(0, 0.5, 'np.exp(X)')

# %%
# Crea un diagrama de dispersión de X versus np.sin(X)
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %% [markdown]
# ¿Qué tal si probamos otro tipo de diagrama? Esta vez veamos un diagrama de barras. Primero crearemos algunos datos.

# %%
# Crea un diccionario de Python de 3 de tus comidas favoritas con
# Las claves del diccionario deben ser el nombre de la comida y los valores su precio

comidas_favoritas = {
    'Pica Pollo': 8.99,
    'Empanada': 12.50,
    'Moro': 3.50
}

# %%
# Crea un gráfico de barras donde el eje x sean las claves del diccionario
# y el eje y sean los valores del diccionario
fig, ax = plt.subplots()
ax.bar(comidas_favoritas.keys(), comidas_favoritas.values())
# Out:
# <BarContainer object of 3 artists>

# %%
# Agrega un título, xlabel e ylabel al diagrama
# Haz el mismo diagrama que el anterior, excepto que esta vez haz que las barras sean horizontales

fig, ax = plt.subplots()
ax.barh(list(comidas_favoritas.keys()), list(comidas_favoritas.values()))

ax.set_title('Comidas Favoritas')
ax.set_xlabel('Precio')
ax.set_ylabel('Plato')
# Out:
# Text(0, 0.5, 'Plato')

# %% [markdown]
# Todo este trazado de alimentos me está dando hambre. Pero tenemos un par de diagramas por hacer.
#
# Veamos un histograma.

# %%
# Crea una matriz NumPy aleatoria de 1000 números distribuidos normalmente usando NumPy y guárdala en X
X = np.random.randn(1000)
print(len(X))
# Crea un gráfico de histograma de X
fig, ax = plt.subplots()
ax.hist(X)
# Out:
# 1000
# (array([ 10.,  61., 131., 202., 219., 190., 118.,  49.,  16.,   4.]),
#  array([-2.68378789, -2.08029729, -1.47680668, -0.87331607, -0.26982546,
#          0.33366514,  0.93715575,  1.54064636,  2.14413696,  2.74762757,
#          3.35111818]),
#  <BarContainer object of 10 artists>)

# %%
# Crea una matriz NumPy de 1000 números aleatorios y guárdala en X
x = np.random.rand(1000)
# Crea un gráfico de histograma de X
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([ 95.,  93.,  94., 112.,  89.,  82., 111., 100., 106., 118.]),
#  array([0.00113618, 0.10100378, 0.20087139, 0.30073899, 0.40060659,
#         0.50047419, 0.60034179, 0.70020939, 0.80007699, 0.89994459,
#         0.99981219]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Observa cómo las distribuciones (dispersión de datos) son diferentes. ¿Por qué difieren?
#
# ¿Qué más puedes averiguar sobre la distribución normal?
#
# ¿Puedes pensar en otros tipos de datos que puedan estar distribuidos normalmente?
#
# Estas preguntas no están directamente relacionadas con la representación gráfica o Matplotlib, pero es útil pensar en ellas.
#
# Ahora, intentemos crear algunos subgráficos. Un subgráfico es otro nombre para una figura con múltiples gráficos en él.

# %%
# Crea un subgráfico vacío con 2 filas y 2 columnas (4 subgráficos en total)
fig, axs = plt.subplots(2, 2)

# %% [markdown]
# Observa cómo el subgráfico tiene múltiples figuras. Ahora, agreguemos datos a cada eje.

# %%
# Crea el mismo gráfico que el anterior con 2 filas y 2 columnas y un tamaño de figura de (10, 5)
fig, axs = plt.subplots(2, 2, figsize=(10, 5))

# Grafica X versus X/2 en los ejes superiores izquierdos
axs[0,0].plot(x, x/2)

# Grafica un gráfico de dispersión de 10 números aleatorios en cada eje en el subgráfico superior derecho
axs[0,1].scatter(np.random.rand(10), np.random.rand(10))

# Grafica un gráfico de barras de las claves y valores de los alimentos favoritos en el subgráfico inferior izquierdo
axs[1,0].bar(comidas_favoritas.keys(), comidas_favoritas.values())

# Grafica un histograma de 1000 números aleatorios distribuidos normalmente en el subgráfico inferior derecho
axs[1,1].hist(np.random.randn(1000))
# Out:
# (array([  4.,  21.,  78., 175., 239., 244., 159.,  58.,  16.,   6.]),
#  array([-3.12334208, -2.49417662, -1.86501115, -1.23584568, -0.60668021,
#          0.02248526,  0.65165073,  1.2808162 ,  1.90998167,  2.53914714,
#          3.1683126 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Ahora hemos visto cómo graficar con Matplotlib y datos directamente. Practiquemos el uso de Matplotlib para graficar con pandas.
#
# Primero necesitaremos importar pandas y crear un DataFrame con el que trabajar.

# %%
# Importa pandas como pd
import pandas as pd

# %%
# Importa '../data/car-sales.csv' en un DataFame llamado car_sales y visualízalo
car_sales =  pd.read_csv('car-sales.csv')
print(car_sales.head())
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Intenta trazar la columna 'Precio' usando la función plot()

# car_sales['Price'].plot() → NO FUNCIONA
# Podria trazarse usando:
# plt.plot(car_sales['Price'])

# %% [markdown]
# ¿Por qué no funciona?
#
# Pista: No son datos numéricos.
#
# En el proceso de convertirlos en datos numéricos, creemos otra columna que sume la cantidad total de ventas y otra que muestre en qué fecha se vendió el automóvil.
#
# Pista: Para sumar una columna de forma acumulativa, busca la función cumsum(). Y para crear una columna de fechas, busca la función date_range().

# %%
# Quitar los símbolos, los dos últimos números de la columna 'Precio' y convertirlos a números
car_sales['Price'] = car_sales['Price'].str.replace('[$,]', '', regex=True).str[:-3].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Agregar una columna llamada 'Ventas totales' a car_sales que suma de forma acumulativa la columna 'Precio'
car_sales['Ventas Totales'] = car_sales['Price'].cumsum()
car_sales

# Agregar una columna llamada 'Fecha de venta' que enumera una serie de fechas sucesivas a partir de hoy (su hoy)
car_sales['Fecha de Venta'] = pd.date_range(start='2025-05-05', periods=len(car_sales), freq='D')

# Ver el DataFrame de car_sales
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Ventas Totales Fecha de Venta
# 0  Toyota  White         150043      4   4000            4000     2025-05-05
# 1   Honda    Red          87899      4   5000            9000     2025-05-06
# 2  Toyota   Blue          32549      3   7000           16000     2025-05-07
# 3     BMW  Black          11179      5  22000           38000     2025-05-08
# 4  Nissan  White         213095      4   3500           41500     2025-05-09
# 5  Toyota  Green          99213      4   4500           46000     2025-05-10
# 6   Honda   Blue          45698      4   7500           53500     2025-05-11
# 7   Honda   Blue          54738      4   7000           60500     2025-05-12
# 8  Toyota  White          60000      4   6250           66750     2025-05-13
# 9  Nissan  White          31600      4   9700           76450     2025-05-14

# %% [markdown]
# Ahora tenemos una columna numérica (Ventas totales) y una columna de fechas (Fecha de venta), visualicémoslas.

# %%
# Usar la función plot() para trazar la columna 'Fecha de venta' en comparación con la columna 'Ventas totales'
car_sales.plot(x='Fecha de Venta', y='Ventas Totales', title='Ventas Totales por Fecha de Venta')
# Out:
# <Axes: title={'center': 'Ventas Totales por Fecha de Venta'}, xlabel='Fecha de Venta'>

# %%
# Convertir la columna 'Precio' a números enteros
car_sales['Price'] = car_sales['Price'].astype(int)

# Crear un diagrama de dispersión de las columnas 'Odómetro (KM)' y 'Precio' utilizando la función plot()
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter', title='Precio vs. Odómetro')
# Out:
# <Axes: title={'center': 'Precio vs. Odómetro'}, xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Cree una matriz NumPy de números aleatorios de tamaño (10, 4) y guárdela en X
m = np.random.rand(10, 4)
m

# Convierta la matriz NumPy X en un DataFrame con columnas llamadas ['a', 'b', 'c', 'd']
mdf = pd.DataFrame(m, columns=['a','b','c','d'])
mdf

# Cree un gráfico de barras del DataFrame
mdf.plot(kind='bar', title='Gráfico de barras numeros aleatorios')
# Out:
# <Axes: title={'center': 'Gráfico de barras numeros aleatorios'}>

# %%
# Cree un gráfico de barras de las columnas 'Marca' y 'Odómetro (KM)' en el DataFrame car_sales
car_sales.plot('Make', 'Odometer (KM)', kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
# Cree un histograma de la columna 'Odómetro (KM)'
car_sales['Odometer (KM)'].plot(kind='hist', title='Histograma de Odometro (KM)')

# car_sales.plot('Odometer (KM)', kind='hist') → ASI NO!!!
# Out:
# <Axes: title={'center': 'Histograma de Odometro (KM)'}, ylabel='Frequency'>

# %%
# Cree un histograma de la columna 'Precio' con 20 intervalos
car_sales['Price'].plot(kind='hist', bins=20, title='Histograma de Precios')
# Out:
# <Axes: title={'center': 'Histograma de Precios'}, ylabel='Frequency'>

# %% [markdown]
# Ahora hemos visto algunos ejemplos de gráficos directamente desde DataFrames utilizando el conjunto de datos car_sales.
#
# Probemos con un conjunto de datos diferente.

# %%
# Importa "../data/heart-disease.csv" y guárdalo en la variable "heart_disease"
heart_disease = pd.read_csv('heart-disease.csv')

# %%
# Visualiza las primeras 10 filas del marco de datos heart_disease
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
# Crea un histograma de la columna "age" con 50 bins
heart_disease['age'].plot(kind='hist', bins=50, title='Histograma de Edad')
# Out:
# <Axes: title={'center': 'Histograma de Edad'}, ylabel='Frequency'>

# %%
# Llama a plot.hist() en el marco de datos heart_disease y cambia el parámetro
# "subplots" a True
heart_disease.plot.hist(subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# Ese gráfico se ve bastante comprimido. Cambiemos el tamaño de la figura.

# %%
# Llama a la misma línea de código anterior, excepto que cambiamos el parámetro "figsize"
# a (10, 30)
heart_disease.plot.hist(subplots=True, figsize=(10, 30))
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# Ahora, intentemos comparar dos variables con la variable objetivo.
#
# Más específicamente, veremos cómo la edad y el colesterol combinados afectan el objetivo en pacientes mayores de 50 años.
#
# Para este próximo desafío, vamos a replicar el siguiente gráfico:
# ![image.png](data:image/png;base64,...)

# %%
# Filtrar pacientes mayores de 50 años
df_filtered = heart_disease[heart_disease['age'] > 50]

# Separar por clase objetivo
df_0 = df_filtered[df_filtered['target'] == 0]
df_1 = df_filtered[df_filtered['target'] == 1]

# Crear el gráfico
plt.figure(figsize=(10, 6))

# Puntos para target = 0
plt.scatter(df_0['age'], df_0['chol'], color='gold', label='0', alpha=0.7)

# Puntos para target = 1
plt.scatter(df_1['age'], df_1['chol'], color='purple', label='1', alpha=0.7)

# Línea horizontal con la media del colesterol
mean_chol = df_filtered['chol'].mean()
plt.axhline(y=mean_chol, color='blue', linestyle='--')

# Títulos y etiquetas
plt.title('Heart Disease and Cholesterol Levels')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.legend(title='Target')
plt.tight_layout()
plt.show()

# %%
# Replique el gráfico anterior de la forma que crea conveniente

# Nota: el método a continuación es solo una forma de hacerlo, el suyo puede ser
# ligeramente diferente

# Cree un DataFrame con pacientes mayores de 50 años

# Cree el gráfico

# Grafique los datos

# Personalice el gráfico

# Agregue una línea media

# %% [markdown]
# Hermoso, ahora ha creado un gráfico de dos variables diferentes, cambiemos el estilo.

# %%
# Verifique qué estilos están disponibles en plt
# Cambie el estilo para usar "seaborn-whitegrid"

# %% [markdown]
# Ahora que se cambió el estilo, volveremos a graficar la misma figura de arriba y veremos cómo se ve.
#
# Si has cambiado el estilo correctamente, debería verse como lo siguiente:
# ![image.png](data:image/png;base64,...)

# %%
# Reproduce la misma figura que la anterior con el estilo "seaborn-whitegrid"

# Crea el gráfico

# Grafica los datos

# Personaliza el gráfico

# Agrega una línea media

# %% [markdown]
# Genial, has cambiado el estilo de los gráficos y la figura se ve diferente, pero los puntos no tienen un color muy bueno.
#
# Cambiemos el parámetro cmap de scatter() así como el parámetro color de axhline() para solucionarlo.
#
# Completar este paso correctamente debería dar como resultado una figura que se vea como esta:
# ![image.png](data:image/png;base64,...)

# %%
# Vuelve a trazar la misma figura que la anterior, excepto que cambia el parámetro "cmap"
# de scatter() a "winter"
# Cambia también el parámetro "color" de axhline() a "red"

# Crea el gráfico

# Grafica los datos

# Personaliza el gráfico

# Agrega una línea media

# %% [markdown]
# ¡Hermoso! Ahora que nuestra figura tiene un esquema de colores actualizado, guardémoslo en un archivo.

# %%
# Guarde la figura actual usando savefig(), el nombre del archivo puede ser el que desee
# Restablezca la figura llamando plt.subplots()
